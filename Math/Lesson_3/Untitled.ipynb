# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x = np.linspace(-10, 10, 200)
y = 3*x + 1
y2 = (-1/3)*x + 1
plt.axis('equal')
plt.plot(x, y)
plt.plot(x, y2)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
x = np.linspace(-np.pi, np.pi, 1000)
y = np.sqrt(np.pi**2 - x**2)
plt.axis('equal')
plt.plot(x, y)
plt.plot(x,-y)

# %%
x = np.linspace(-np.pi, np.pi, 1000)
y = np.sqrt(np.pi**2 - x**2)
plt.axis('equal')
plt.plot(x, y/2)
plt.plot(x,-y/2)
plt.plot(x+np.pi*3, y*1.5)
plt.plot(x+np.pi*3,-y*1.5)

# %%
y = np.linspace(-np.pi, np.pi, 1000)
x = np.sqrt(np.pi**2 + x**2)
plt.axis('equal')
plt.plot(x, y)
plt.plot(-x, y)
x = np.linspace(-np.pi, np.pi, 1000)
y = np.sqrt(np.pi**2 + x**2)
plt.axis('equal')
plt.plot(x+np.pi*3, y)
plt.plot(x+np.pi*3, -y)

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = figure()
ax = Axes3D(fig)
x = np.arange(-5, 5, 0.5)
y = np.arange(-5, 5, 0.5)
x, y = np.meshgrid(x, y)
z = 4*x + 5*y + 2
z2 = 4*x + 5*y + 100
ax.plot_surface(x, y, z)
ax.plot_surface(x, y, z2)

# %%
fig = figure()
ax = Axes3D(fig)
x = np.arange(-5, 5, 0.5)
y = np.arange(-5, 5, 0.5)
x, y = np.meshgrid(x, y)
z = 4*x**2 + 5*y + 100
z2 = 4*x**2 - 5*y**2 + 2
ax.plot_surface(x, y, z)
ax.plot_surface(x, y, z2)

# %%
x = np.linspace(-3*np.pi, 3*np.pi, 1000)
k1 = 2
a1 = 3
b1 = 5
k2 = 4
a2 = 8
b2 = -4
k3 = 3
a3 = -8
b3 = -5
y1 = k1*np.cos(x-a1) + b1
y2 = k2*np.cos(x-a2) + b2
y3 = k3*np.cos(x-a3) + b3
plt.axis('equal')
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)

# %%
polar_coor = input("Введите полярный радиус и угол в полярной системе координат через пробел: ").split()
print(f"В декартовой системе координат: ({int(polar_coor[0])*cos(int(polar_coor[1])*np.pi/180):.2f}, {int(polar_coor[0])*sin(int(polar_coor[1])*np.pi/180):.2f})")
# Out:
# Введите полярный радиус и угол в полярной системе координат через пробел: 3 60
# В декартовой системе координат: (1.50, 2.60)

# %%
x = np.linspace(0, 2*np.pi, 100)
y = np.full(100, 5)

plt.polar(x, y)

# %%
x = np.linspace(0, np.pi/6, 2)
y = (0, 3)
plt.polar(x, y)

# %%
# y = x2 – 1
# exp(x) + x∙(1 – y) = 1
import scipy
from scipy.optimize import fsolve
import matplotlib.ticker as ticker
x = np.linspace(-10, 10, 201)
plt.subplots(figsize=(10, 10))
plt.plot(x, 1-(1-np.exp(x))/x)
plt.plot(x, x**2 - 1)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-10,5)
plt.ylim(-2,20)
plt.xticks(np.arange(-10, 5, 0.5), rotation=90)
plt.yticks(np.arange(-2, 20, 0.5))
plt.grid(True)
plt.show()
def equations(p):
    x, y = p
    return (y - x**2 + 1, y - 1+(1-np.exp(x))/x)

x1, y1 =  fsolve(equations, (-2, 0))
x2, y2 =  fsolve(equations, (2, 5))
x3, y3 =  fsolve(equations, (4, 14))
print("Корни системы уравнений (x, y)")
print (f"{x1}, {y1}")
print (f"{x2}, {y2}")
print (f"{x3}, {y3}")
# Out:
# <ipython-input-15-17f75246cd7c>:8: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x, 1-(1-np.exp(x))/x)
# Корни системы уравнений (x, y)
# -1.5818353528958515, 1.5022030836713072
# 2.618145573085375, 5.854686241865328
# 4.200105841155167, 16.640889076905783

# %%
x = np.linspace(-10, 10, 201)
plt.subplots(figsize=(10, 10))
plt.plot(x, 1-(1-np.exp(x))/x)
plt.plot(x, x**2 - 1)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-10,5)
plt.ylim(-2,20)
plt.xticks(np.arange(-10, 5, 0.5), rotation=90)
plt.yticks(np.arange(-2, 20, 0.5))
plt.grid(True)
plt.show()
def equations(p):
    x, y = p
    return (y - x**2 + 1, y - 1+(1-np.exp(x))/x)

x1, y1 =  fsolve(equations, (-2, 0))
x2, y2 =  fsolve(equations, (2, 5))
x3, y3 =  fsolve(equations, (4, 14))
print("Корни системы уравнений (x, y)")
print (f"{x1}, {y1}")
print (f"{x2}, {y2}")
print (f"{x3}, {y3}")
# Out:
# <ipython-input-16-a186d04d5d41>:3: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x, 1-(1-np.exp(x))/x)
# Корни системы уравнений (x, y)
# -1.5818353528958515, 1.5022030836713072
# 2.618145573085375, 5.854686241865328
# 4.200105841155167, 16.640889076905783
